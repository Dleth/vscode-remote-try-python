# %%
import pandas as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.array([[1, -1], [1, 1], [-1, 1], [-1, -1]]), columns=['x', 'y'])

# %%
plt.scatter(df['x'], df['y'])
